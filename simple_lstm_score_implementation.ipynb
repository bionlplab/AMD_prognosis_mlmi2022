# %%
from src.simple_lstm_score import *

# %%
train_rnn_kfold("/home/jl5307/current_research/AMD_prediction/results/simple_lstm_score/", 
                "/home/jl5307/current_research/AMD_prediction/data/amd_eye_score_dict.pkl",
               50, 16, 10, 10, 4)
# Out:
# load data...
# split the dataset into k-fold...
# build and initialize model for 1-th fold...
# start training...
# 286/286 [==============================] - 9s 21ms/step
# epoch:1, training loss:2.826222
# epoch:1, validation MAD:1.440729
# 286/286 [==============================] - 6s 21ms/step
# epoch:2, training loss:1.642667
# epoch:2, validation MAD:1.129916
# 286/286 [==============================] - 6s 21ms/step
# epoch:3, training loss:1.430048
# epoch:3, validation MAD:1.036911
# 286/286 [==============================] - 6s 21ms/step
# epoch:4, training loss:1.362471
# epoch:4, validation MAD:0.977304
# 286/286 [==============================] - 6s 21ms/step
# epoch:5, training loss:1.333962
# epoch:5, validation MAD:0.943714
# 286/286 [==============================] - 6s 21ms/step
# epoch:6, training loss:1.312627
# epoch:6, validation MAD:0.933656
# 286/286 [==============================] - 6s 21ms/step
# epoch:7, training loss:1.300744
# ...
