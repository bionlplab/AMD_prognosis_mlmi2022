# %%
from src.convrnn_main import *

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="2"

# %%
sl = list(range(0,10))

# %%
bootstrap_train_lstm("/home/jl5307/current_research/AMD_prediction/results/convlstm/td5/convlstm_u256_b32_e20_r10/", 
                             "/home/jl5307/current_research/AMD_prediction/img_data/data_dictionary/longitudinal_sequential_prediction_td5_min5_data_dict_unrolled.pkl",
                             "/home/jl5307/current_research/AMD_prediction/results/resnet101_binary/b16_lr0005_e20_detection_imagenet/extracted_feature_dict.pkl",
                             10, 20, 32, 256, 2048, 0.0005, 0.0001, [0.03, 0.97], lr_scheduling=[2000, 0.9], seed_list=None)
# Out:
# load data...
# 1-th repetition...
# using the full train set...
# build and initialize models...
# batch loss: 0.021477
#    1/1020 [..............................] - ETA: 53:01batch loss: 0.013664
# batch loss: 0.009071
#    3/1020 [..............................] - ETA: 39s  batch loss: 0.006663
# batch loss: 0.002241
#    5/1020 [..............................] - ETA: 34sbatch loss: 0.001041
# batch loss: 0.002381
#    7/1020 [..............................] - ETA: 33sbatch loss: 0.000527
# batch loss: 0.001818
#    9/1020 [..............................] - ETA: 33sbatch loss: 0.000957
# batch loss: 0.000295
# batch loss: 0.000049
#   12/1020 [..............................] - ETA: 30sbatch loss: 0.000423
# batch loss: 0.092098
# batch loss: 0.000570
#   15/1020 [..............................] - ETA: 29sbatch loss: 0.000097
# batch loss: 0.000963
#   17/1020 [..............................] - ETA: 29sbatch loss: 0.000544
# batch loss: 0.000705
# ...
