# %%
from src.resnet_main import *

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="3"

# %%
train_resnet_binary_detection("/home/jl5307/current_research/AMD_prediction/results/resnet101_binary/b16_lr0005_e20_detection_random/", 
                              "/home/jl5307/current_research/AMD_prediction/img_data/img_files/", 
                              "/home/jl5307/current_research/AMD_prediction/img_data/data_dictionary/binary_detection_data_dict.pkl", [3,4,23,3], 
                              20, 16, 0.0005, 0.0001, 1, 256, 0.875, [0.13, 0.87], prediction="binary", 
                              augment=True, lr_scheduling=True, use_pretrain=None)
# Out:
# load data...
# build and initialize ResNet...
# initialize with random weights...
# batch loss: 0.072516
# ...
#  622/2873 [=====>........................] - ETA: 52:29batch loss: 0.094820
# ...
# ...
# 2873/2873 [==============================] - 4026s 1s/step
# epoch:1, training loss:0.082294
# epoch:1, validation acc:0.509451
# Best model: at epoch 1, best model auc:0.509451
# calculate AUC using the best model on the test set
# test AUC: 0.529453
# saving results...
# /home/jl5307/current_research/virtualenvs/python3-workspace/lib/python3.6/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
