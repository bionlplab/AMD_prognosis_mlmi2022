# %%
from src.resnet_main import *

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="2"

# %%
train_resnet_amd_detection("/home/jl5307/current_research/AMD_prediction/results/resnet101_amd_detection/fold4/", 
                              "/home/jl5307/current_research/AMD_prediction/img_data/img_files/", 
                              "/home/jl5307/current_research/AMD_prediction/img_data/5_fold/five_fold_amd_detection_data_dict.pkl", 
                           [3,4,23,3], 20, 32, 0.0005, 0.0001, 1, 256, 0.875, [0.13, 0.87], prediction="binary", 
                              augment=True, lr_scheduling=[800, 0.9], specify_fold=4, use_pretrain="imagenet", testing=False)
# Out:
# load data...
# build and initialize ResNet...
# use ResNet pretrained with imagenet...
# batch loss: 0.179823
# ...
# 414/414 [==============================] - 776s 2s/step
# epoch:1, training loss:0.107676
# epoch:1, validation acc:0.455902
# Best model: at epoch 1, best model auc:0.455902
# calculate AUC using the best model on the test set
# test AUC: 0.443993
# saving results...
# /home/jl5307/current_research/virtualenvs/python3-workspace/lib/python3.6/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
load_data("/home/jl5307/current_research/AMD_prediction/results/resnet101_amd_detection/resnet_validation_auc.pkl")
# Out:
# [0.45590243]
