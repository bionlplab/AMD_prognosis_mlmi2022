# %%
import numpy as np
import pickle

# %%
def load_data(data_path):
    data = pickle.load(open(data_path, 'rb'))

    return data

# %%
d = load_data("/home/jl5307/current_research/AMD_prediction/img_data/data_dictionary/longitudinal_sequential_prediction_timedelta2_data_dict_min5.pkl")

# %%
eye_data = np.array(d["train_set"]["eye_list"])
# Out:
# /home/jl5307/current_research/virtualenvs/python3-workspace/lib/python3.6/site-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """Entry point for launching an IPython kernel.

# %%
np.random.seed()

# %%
ind = np.random.randint(len(eye_data), size=len(eye_data))

# %%
ind.sort()

# %%
ind
# Out:
# array([   0,    0,    0, ..., 5346, 5347, 5348])

# %%
list(eye_data[ind])
# Out:
# [['56516 QUA F2 RE LS.jpg',
#   '56516 04 F2 RE LS.jpg',
#   '56516 06 F2 RE LS.jpg',
#   '56516 08 F2 RE LS.jpg',
#   '56516 10 F2 RE LS.jpg',
#   '56516 12 F2 RE LS.jpg',
#   '56516 14 F2 RE LS.jpg',
#   '56516 17 F2 RE LS.jpg',
#   '56516 18 F2 RE LS.jpg',
#   '56516 20 F2 RE LS.jpg',
#   '56516 22 F2 RE LS.jpg'],
#  ['56516 QUA F2 RE LS.jpg',
#   '56516 04 F2 RE LS.jpg',
#   '56516 06 F2 RE LS.jpg',
#   '56516 08 F2 RE LS.jpg',
#   '56516 10 F2 RE LS.jpg',
#   '56516 12 F2 RE LS.jpg',
#   '56516 14 F2 RE LS.jpg',
#   '56516 17 F2 RE LS.jpg',
#   '56516 18 F2 RE LS.jpg',
#   '56516 20 F2 RE LS.jpg',
#   '56516 22 F2 RE LS.jpg'],
#  ['56516 QUA F2 RE LS.jpg',
#   '56516 04 F2 RE LS.jpg',
#   '56516 06 F2 RE LS.jpg',
#   '56516 08 F2 RE LS.jpg',
#   '56516 10 F2 RE LS.jpg',
#   '56516 12 F2 RE LS.jpg',
#   '56516 14 F2 RE LS.jpg',
#   '56516 17 F2 RE LS.jpg',
#   '56516 18 F2 RE LS.jpg',
#   '56516 20 F2 RE LS.jpg',
#   '56516 22 F2 RE LS.jpg'],
#  ['56516 QUA F2 RE LS.jpg',
# ...
