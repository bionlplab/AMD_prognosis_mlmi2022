# %%
from src.convrnn_main import *

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
train_resnetlstm_module("/home/jl5307/current_research/AMD_prediction/results/convlstm/resnetlstm_module_u256_b2_e20/random/",
                        "/home/jl5307/current_research/AMD_prediction/img_data/img_files/",
                        "/home/jl5307/current_research/AMD_prediction/img_data/data_dictionary/longitudinal_sequential_prediction_data_dict.pkl",
                        [3, 4, 23, 3], 20, 2, 256, 0.0005, 0.0001, 256, 0.875, class_weight=[0.1, 0.9], augment=True, lr_scheduling=True, 
                        use_pretrain=None, pretrained_weights_path=None, pretrained_config_path=None, testing=False)
# Out:
# load data...
# build and initialize models...
# initialize with random weights...
# batch loss: 0.081557
# ...
#   20/2675 [..............................] - ETA: 55:06
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-76c273cfc833> in <module>
#       3                         "/home/jl5307/current_research/AMD_prediction/img_data/data_dictionary/longitudinal_sequential_prediction_data_dict.pkl",
#       4                         [3, 4, 23, 3], 20, 2, 256, 0.0005, 0.0001, 256, 0.875, class_weight=[0.1, 0.9], augment=True, lr_scheduling=True,
# ----> 5                         use_pretrain=None, pretrained_weights_path=None, pretrained_config_path=None, testing=False)
#
# ...

# %%
train_resnetlstm_module("/home/jl5307/current_research/AMD_prediction/results/convlstm/testing/",
                        "/home/jl5307/current_research/AMD_prediction/img_data/img_files/",
                        "/home/jl5307/current_research/AMD_prediction/img_data/data_dictionary/longitudinal_sequential_prediction_data_dict.pkl",
                        [3, 4, 23, 3], 20, 2, 256, 0.0005, 0.0001, 256, 0.875, class_weight=[0.1, 0.9], augment=True, lr_scheduling=True, 
                        use_pretrain=None, pretrained_weights_path="/home/jl5307/current_research/AMD_prediction/results/resnet101_binary/b16_lr0005_e20_detection_random/resnet_best_model.npy",
                        pretrained_config_path="/home/jl5307/current_research/AMD_prediction/results/resnet101_binary/b16_lr0005_e20_detection_random/resnet_config.pkl",
                        testing=True)
# Out:
# load data...
# build and initialize models...
# use pretrained weights based on random initialization...
# batch loss: 0.068397
# ...
# 580/580 [==============================] - 542s 934ms/step
# epoch:1, training loss:0.076769
# epoch:1, validation AUC:0.504696
# Best model: at epoch 1, best model auc:0.504696
# calculate AUC using the best model on the test set
# test auc:0.504696
# saving results...
# /home/jl5307/current_research/virtualenvs/python3-workspace/lib/python3.6/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
